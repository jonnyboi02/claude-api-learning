# %%
#install dependencies

# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.104.1)
# Requirement already satisfied: python-dotenv in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.16)
# Requirement already satisfied: certifi in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#load env variables

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#create an api client

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message (messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message (messages, text):
    assisant_message = {"role": "assistant", "content": text}
    messages.append(assisant_message)




def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json
messages = []
add_user_message(messages, "Write me a function to retrun 5+5 as python")
add_assistant_message(messages, "```python")

text = chat(messages, stop_sequences=["```"])
print(text)
print(json.loads(text))
# Out:
# def add_five_and_five():
#     return 5 + 5
#
# # Call the function
# result = add_five_and_five()
# print(result)  # Output: 10
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[53], line 8
#       4 add_assistant_message(messages, "```python")
#       5
#       6 text = chat(messages, stop_sequences=["```"])
#       7 print(text)
# ----> 8 print(json.loads(text))
#
# File c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     347     s = s.decode(detect_encoding(s), 'surrogatepass')
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#     354     cls = JSONDecoder
#
# File c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File c:\Users\Jonathan\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)
