# %%
#install dependencies

# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (0.105.2)
# Requirement already satisfied: python-dotenv in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (1.2.1)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: sniffio in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: certifi in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: h11>=0.16 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jonathanchiu/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#load env variables

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#create an api client

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message (messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message (messages, text):
    assisant_message = {"role": "assistant", "content": text}
    messages.append(assisant_message)




def chat (messages, system=None, temperature=1.0):   
    params = {
        "model" : model,
        "max_tokens" : 1000,
        "messages":messages,
        "temperature": temperature
    }
    
    if system != None:
       params["system"] = system

    message = client.messages.create(**params)
        

    return message.content[0].text

# %%
messages = []
add_user_message(messages, "Write me a sentence about palantir")

with client.messages.stream(

        model=model,
        max_tokens=1000, 
        messages = messages,
          
) as stream:
    for event in stream.text_stream:
        print(event, end="")

stream.get_final_message().content[0]
# Out:
# Here is a sentence about Palantir:
#
# **Palantir Technologies is a data analytics and software company known for its powerful data integration platforms, Gotham and Foundry, which are used by government agencies and large corporations to analyze vast amounts of complex data.**
# ParsedTextBlock(citations=None, text='Here is a sentence about Palantir:\n\n**Palantir Technologies is a data analytics and software company known for its powerful data integration platforms, Gotham and Foundry, which are used by government agencies and large corporations to analyze vast amounts of complex data.**', type='text', parsed_output=None)
